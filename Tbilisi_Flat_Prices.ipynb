# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Tbilisi.csv")

# %%
df = df[(df.T != 0).any()]
df = df.drop("Unnamed: 0",axis=1)

# %%
df = df[df.price < 150000]

# %%
x = [41, 41.5, 42]


#flats under $150k
df.plot(kind="scatter", x="longitudes", y="latitudes", label = "price", figsize = (16,8),
        c = df["price"], cmap = plt.get_cmap("jet"))

plt.title(label = "Tbilisi flats under $150k")
plt.legend()

# %%
#flats between $150k - $500k

df2 = pd.read_csv("Tbilisi.csv")
df2 = df2[(df2.T != 0).any()]

df2 = df2[df2.price > 150000]
df2 = df2[df2.price < 500000]

# %%
#$150k - $500k

df2.plot(kind="scatter", x="longitudes", y="latitudes", label = "price", figsize = (16,8),
        c = df2["price"], cmap = plt.get_cmap("jet"))

plt.title(label = "Tbilisi flats between $150k - $500K")
# Out:
# Text(0.5, 1.0, 'Tbilisi flats between $150k - $500K')

# %%
#flats above $500k - $1kk

df3 = pd.read_csv("Tbilisi.csv")
df3 = df3[(df3.T != 0).any()]
df3 = df3[df3["price"] >= 500000]
df3 = df3[df3["price"] <= 1000000]

# %%
#$500k - $1kk

df3.plot(kind="scatter", x="longitudes", y="latitudes", label = "price", figsize = (16,8),
        c = df3["price"], cmap = plt.get_cmap("jet"))
plt.title(label = "Tbilisi flats be")
# Out:
# <AxesSubplot:xlabel='longitudes', ylabel='latitudes'>

# %%
#flats above$1kk

df4 = pd.read_csv("Tbilisi.csv")
df4 = df4[(df4.T != 0).any()]
df4 = df4[df4["price"] > 1000000]

# %%
# +$1kk

df4.plot(kind="scatter", x="longitudes", y="latitudes", label = "price", figsize = (16,8),
        c = df4["price"], cmap = plt.get_cmap("jet"))
# Out:
# <AxesSubplot:xlabel='longitudes', ylabel='latitudes'>
